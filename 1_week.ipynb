# %%
print('Hallo World!!!')

# %%
'''Repitition in first week
    - data types
    - list
    - dict
    - functions '''

# %%
#Lists (списки)

# %%
my_list = [1, 2, 3, 7, 2, 465, 6, 13, 97, 334, 222, 5] #произвольный список
print(my_list)

# %%
my_list_generetion = [int(elem) for elem in range(15)] #генератор списка [0, 1, 2, ..., 14]
print(my_list_generetion)

# %%
my_list.sort()
print(my_list)

# %%
ml_g = my_list_generetion
print(ml_g)

# %%
ml_g = ml_g[-1:-len(ml_g)-1:-1]
print(ml_g)

# %%
e = ml_g.pop(-1)
print(e)
print(ml_g)

# %%
print(sorted(ml_g))

# %%
print(my_list.index(222))

# %%
print(my_list.count(2))

# %%
print(my_list.count(0))

# %%
new_list = my_list.extend(ml_g)
print(new_list)

# %%
print(my_list)

# %%
my_list.sort()

# %%
my_list.reverse()

# %%
print(my_list)

# %%
print(len(my_list))
print(max(my_list))
print(min(my_list))

# %%
new_list = my_list[::-1]
print(new_list)
